# %%
# %pip install matplotlib
# %pip install pandas
# %pwd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'c:\\Users\\PC\\OneDrive\\Desktop\\CforAZ\\CforAZ_Data_Analytics'

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('c:\\Users\\PC\\OneDrive\\Desktop\\CforAZ\\CforAZ_Data_Analytics\\processed_CFAZ Modeling Data.csv')

ax = df.plot(x='Max Give', y='Log_Total Contributions')
ax.set_xlabel("X Values")
ax.set_ylabel("Y Values")
plt.grid(True)
plt.show()
